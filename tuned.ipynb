# %%
# runs\detect\train11\weights\best.pt


from ultralytics import YOLO

model = YOLO("runs/detect/train11/weights/best.pt")

# %%
model.predict(
    source="test_al.png",
    imgsz=64,
    conf=0.01,
    save=True
)
# Out:
# image 1/1 s:\YOLO\test_al.png: 64x64 1 alpaca, 8.4ms
# Speed: 0.3ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 64, 64)
# Results saved to S:\YOLO\runs\detect\predict10
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'alpaca'}
#  obb: None
#  orig_img: array([[[ 22,  21,  20],
#          [ 22,  21,  20],
#          [ 22,  21,  20],
#          ...,
#          [ 22,  21,  20],
#          [ 22,  21,  20],
#          [ 22,  21,  20]],
#
#         [[ 22,  21,  20],
#          [ 22,  21,  20],
#          [ 22,  21,  20],
#          ...,
#          [ 22,  21,  20],
#          [ 22,  21,  20],
#          [ 22,  21,  20]],
#
#         [[ 98, 102, 110],
#          [ 98, 102, 110],
#          [ 97, 102, 110],
#          ...,
#          [101, 101, 113],
#          [101, 101, 113],
#          [101, 101, 113]],
#
#         ...,
#
# ...
