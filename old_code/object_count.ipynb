# %%
from ultralytics import solutions
import cv2

# %%
import cv2

from ultralytics import solutions


def count_objects_in_region(video_path, output_video_path, model_path):
    """Count objects in a specific region within a video."""
    cap = cv2.VideoCapture(video_path)
    assert cap.isOpened(), "Error reading video file"
    w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
    video_writer = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

    region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]
    counter = solutions.ObjectCounter(show=True, region=region_points, model=model_path)

    while cap.isOpened():
        success, im0 = cap.read()
        if not success:
            print("Video frame is empty or processing is complete.")
            break
        results = counter(im0)
        video_writer.write(results.plot_im)

    cap.release()
    video_writer.release()
    cv2.destroyAllWindows()


count_objects_in_region("data/marathon.mp4", "data/output_video.avi", "yolo11n.pt")
# Out:
# Ultralytics Solutions:  {'source': None, 'model': 'yolo11n.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': [(20, 400), (1080, 400), (1080, 360), (20, 360)], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# 0: 1080x1920 25.8ms, 5 person, 2 truck, 2 car
# Speed: 348.4ms track, 25.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 1: 1080x1920 6.5ms, 5 person, 2 truck, 2 car
# Speed: 89.7ms track, 6.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 2: 1080x1920 5.5ms, 5 person, 2 truck, 2 car
# Speed: 81.2ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 3: 1080x1920 5.9ms, 5 person, 2 truck, 1 car
# Speed: 81.7ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 4: 1080x1920 6.0ms, 5 person, 2 truck, 2 car
# Speed: 83.0ms track, 6.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 5: 1080x1920 5.1ms, 5 person, 2 truck, 2 car
# Speed: 82.5ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 6: 1080x1920 5.1ms, 6 person, 2 truck, 2 car
# Speed: 81.4ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 7: 1080x1920 6.7ms, 5 person, 2 truck, 2 car
# Speed: 82.7ms track, 6.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 8: 1080x1920 5.6ms, 5 person, 2 truck, 2 car
# Speed: 94.4ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 9: 1080x1920 5.8ms, 6 person, 2 truck, 2 car
# Speed: 76.1ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 10: 1080x1920 6.2ms, 6 person, 2 truck, 2 car
# Speed: 80.0ms track, 6.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 11: 1080x1920 6.0ms, 6 person, 2 truck, 3 car
# Speed: 74.9ms track, 6.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 12: 1080x1920 6.3ms, 6 person, 2 truck, 2 car
# Speed: 72.7ms track, 6.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 13: 1080x1920 5.7ms, 4 person, 2 truck, 3 car
# Speed: 75.1ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 14: 1080x1920 5.6ms, 5 person, 2 truck, 3 car
# Speed: 73.1ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 15: 1080x1920 5.3ms, 5 person, 2 truck, 2 car
# Speed: 80.3ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 16: 1080x1920 7.1ms, 5 person, 2 truck, 3 car
# Speed: 78.3ms track, 7.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 17: 1080x1920 6.2ms, 5 person, 3 truck, 3 car
# Speed: 77.7ms track, 6.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 18: 1080x1920 5.9ms, 5 person, 2 truck, 2 car
# Speed: 76.8ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 19: 1080x1920 6.1ms, 5 person, 3 truck, 2 car
# Speed: 77.7ms track, 6.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 20: 1080x1920 5.8ms, 4 person, 3 truck, 2 car
# Speed: 82.9ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 21: 1080x1920 4.8ms, 4 person, 3 truck, 3 car
# Speed: 70.2ms track, 4.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 22: 1080x1920 6.1ms, 5 person, 3 truck, 3 car
# Speed: 78.3ms track, 6.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 23: 1080x1920 7.2ms, 4 person, 3 truck, 2 car
# Speed: 79.3ms track, 7.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 24: 1080x1920 5.9ms, 4 person, 2 truck, 2 car
# Speed: 87.4ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 25: 1080x1920 5.7ms, 4 person, 2 truck, 3 car
# Speed: 76.4ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 26: 1080x1920 4.7ms, 4 person, 2 truck, 3 car
# Speed: 69.8ms track, 4.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 27: 1080x1920 6.1ms, 4 person, 3 truck, 2 car
# Speed: 79.9ms track, 6.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 28: 1080x1920 5.5ms, 4 person, 2 truck, 2 car
# Speed: 76.3ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 29: 1080x1920 5.4ms, 4 person, 2 truck, 1 car
# Speed: 78.5ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 30: 1080x1920 5.3ms, 4 person, 2 truck, 1 car
# Speed: 73.0ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 31: 1080x1920 5.9ms, 5 person, 2 truck, 1 car
# Speed: 74.4ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 32: 1080x1920 5.1ms, 7 person, 2 truck, 1 car
# Speed: 67.5ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 33: 1080x1920 5.6ms, 6 person, 2 truck, 1 car
# Speed: 68.6ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 34: 1080x1920 5.6ms, 5 person, 2 truck, 2 car
# Speed: 72.7ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 35: 1080x1920 5.7ms, 5 person, 2 truck, 2 car
# Speed: 72.7ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 36: 1080x1920 5.9ms, 5 person, 3 truck, 2 car
# Speed: 77.3ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 37: 1080x1920 5.8ms, 4 person, 4 truck, 2 car
# Speed: 75.2ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 38: 1080x1920 5.6ms, 5 person, 4 truck, 2 car
# Speed: 67.2ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 39: 1080x1920 5.8ms, 5 person, 3 truck, 3 car
# Speed: 67.1ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 40: 1080x1920 5.0ms, 5 person, 2 truck
# Speed: 72.5ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 41: 1080x1920 6.0ms, 5 person, 2 truck, 2 car
# Speed: 70.7ms track, 6.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 42: 1080x1920 5.7ms, 5 person, 2 truck, 2 car
# Speed: 73.9ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 43: 1080x1920 5.5ms, 4 person, 2 truck, 2 car
# Speed: 75.1ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 44: 1080x1920 5.7ms, 4 person, 2 truck, 2 car
# Speed: 75.1ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 45: 1080x1920 5.8ms, 4 person, 2 truck, 2 car
# Speed: 74.9ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 46: 1080x1920 5.7ms, 4 person, 2 truck, 2 car
# Speed: 76.3ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 47: 1080x1920 5.5ms, 4 person, 2 truck, 2 car
# Speed: 71.0ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 48: 1080x1920 5.5ms, 4 person, 2 truck, 2 car
# Speed: 71.3ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 49: 1080x1920 4.6ms, 4 person, 2 truck, 1 car
# Speed: 72.6ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 50: 1080x1920 5.6ms, 4 person, 2 truck, 2 car
# Speed: 76.1ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 51: 1080x1920 4.5ms, 4 person, 2 truck, 1 car
# Speed: 73.5ms track, 4.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 52: 1080x1920 5.8ms, 4 person, 3 truck, 2 car
# Speed: 74.7ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 53: 1080x1920 5.4ms, 3 person, 2 truck, 1 car
# Speed: 77.8ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 54: 1080x1920 5.5ms, 4 person, 2 truck, 2 car
# Speed: 72.8ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 55: 1080x1920 5.7ms, 3 person, 3 truck, 2 car
# Speed: 76.7ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 56: 1080x1920 4.9ms, 4 person, 2 truck, 2 car
# Speed: 71.8ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 57: 1080x1920 5.4ms, 4 person, 2 truck, 1 car
# Speed: 74.9ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 58: 1080x1920 7.7ms, 4 person, 2 truck
# Speed: 94.2ms track, 7.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 59: 1080x1920 4.6ms, 4 person, 2 truck
# Speed: 70.6ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 60: 1080x1920 5.0ms, 3 person, 2 truck
# Speed: 76.0ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 61: 1080x1920 4.4ms, 3 person, 2 truck, 2 car
# Speed: 66.7ms track, 4.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 62: 1080x1920 5.5ms, 3 person, 2 truck, 2 car
# Speed: 77.1ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 63: 1080x1920 5.4ms, 3 person, 2 truck, 1 car
# Speed: 86.6ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 64: 1080x1920 5.9ms, 3 person, 2 truck, 1 car
# Speed: 82.5ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 65: 1080x1920 4.7ms, 3 person, 2 truck, 1 car
# Speed: 80.9ms track, 4.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 66: 1080x1920 5.3ms, 3 person, 2 truck, 1 car
# Speed: 80.0ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 67: 1080x1920 6.0ms, 3 person, 2 truck, 1 car
# Speed: 85.6ms track, 6.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 68: 1080x1920 5.5ms, 3 person, 2 truck, 2 car
# Speed: 80.5ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 69: 1080x1920 5.6ms, 3 person, 2 truck, 2 car
# Speed: 81.3ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 70: 1080x1920 5.1ms, 3 person, 2 truck
# Speed: 80.1ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 71: 1080x1920 5.2ms, 3 person, 2 truck, 1 car
# Speed: 76.8ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 72: 1080x1920 5.3ms, 3 person, 2 truck, 1 car
# Speed: 80.2ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 73: 1080x1920 5.3ms, 3 person, 2 truck, 1 car
# Speed: 84.0ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 74: 1080x1920 5.0ms, 3 person, 2 truck
# Speed: 80.0ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 75: 1080x1920 5.8ms, 3 person, 2 truck
# Speed: 82.8ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 76: 1080x1920 5.9ms, 4 person, 2 truck, 2 car
# Speed: 86.2ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 77: 1080x1920 6.7ms, 5 person, 2 truck, 1 car
# Speed: 88.5ms track, 6.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 78: 1080x1920 4.9ms, 4 person, 2 truck
# Speed: 88.9ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 79: 1080x1920 5.4ms, 4 person, 2 truck, 1 car
# Speed: 79.6ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 80: 1080x1920 5.9ms, 4 person, 2 truck, 2 car
# Speed: 74.5ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 81: 1080x1920 5.6ms, 4 person, 2 truck, 2 car
# Speed: 80.0ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 82: 1080x1920 6.0ms, 4 person, 2 truck, 2 car
# Speed: 76.5ms track, 6.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 83: 1080x1920 5.5ms, 4 person, 2 truck, 2 car
# Speed: 84.7ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 84: 1080x1920 6.1ms, 4 person, 2 truck, 1 car
# Speed: 85.5ms track, 6.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 85: 1080x1920 6.2ms, 4 person, 2 truck, 2 car
# Speed: 89.3ms track, 6.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 86: 1080x1920 4.7ms, 4 person, 2 truck, 2 car
# Speed: 84.2ms track, 4.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 87: 1080x1920 6.8ms, 4 person, 2 truck, 2 car
# Speed: 85.6ms track, 6.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 88: 1080x1920 5.5ms, 4 person, 2 truck
# Speed: 88.3ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 89: 1080x1920 5.4ms, 4 person, 2 truck, 2 car
# Speed: 85.6ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 90: 1080x1920 4.6ms, 4 person, 2 truck
# Speed: 68.7ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 91: 1080x1920 5.9ms, 4 person, 2 truck, 2 car
# Speed: 77.6ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 92: 1080x1920 5.3ms, 4 person, 2 truck, 1 car
# Speed: 77.0ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 93: 1080x1920 5.2ms, 4 person, 2 truck, 1 car
# Speed: 75.2ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 94: 1080x1920 5.7ms, 4 person, 2 truck, 1 car
# Speed: 72.8ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 95: 1080x1920 5.8ms, 4 person, 2 truck, 2 car
# Speed: 76.8ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 96: 1080x1920 5.7ms, 4 person, 2 truck, 1 car
# Speed: 70.0ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 97: 1080x1920 5.6ms, 4 person, 2 truck, 1 car
# Speed: 73.2ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 98: 1080x1920 6.0ms, 4 person, 2 truck
# Speed: 79.1ms track, 6.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 99: 1080x1920 5.5ms, 4 person, 2 truck, 1 car
# Speed: 87.1ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 100: 1080x1920 5.5ms, 4 person, 2 truck
# Speed: 76.0ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 101: 1080x1920 5.3ms, 4 person, 2 truck, 1 car
# Speed: 75.7ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 102: 1080x1920 5.0ms, 4 person, 2 truck
# Speed: 67.8ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 103: 1080x1920 5.2ms, 4 person, 2 truck
# Speed: 80.0ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 104: 1080x1920 5.3ms, 4 person, 2 truck
# Speed: 79.8ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 105: 1080x1920 5.2ms, 4 person, 2 truck
# Speed: 81.5ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 106: 1080x1920 5.1ms, 4 person, 2 truck
# Speed: 78.9ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 107: 1080x1920 5.4ms, 4 person, 2 truck
# Speed: 76.9ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 108: 1080x1920 5.3ms, 4 person, 2 truck
# Speed: 78.4ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 109: 1080x1920 5.4ms, 4 person, 2 truck
# Speed: 92.8ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 110: 1080x1920 5.4ms, 4 person, 2 truck, 1 car
# Speed: 78.7ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 111: 1080x1920 5.1ms, 4 person, 2 truck, 1 car
# Speed: 74.5ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 112: 1080x1920 5.4ms, 4 person, 2 truck, 1 car
# Speed: 80.7ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 113: 1080x1920 5.4ms, 4 person, 2 truck, 1 car
# Speed: 79.5ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 114: 1080x1920 5.3ms, 4 person, 2 truck, 1 car
# Speed: 80.1ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 115: 1080x1920 5.3ms, 4 person, 2 truck, 1 car
# Speed: 78.7ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 116: 1080x1920 5.4ms, 4 person, 2 truck, 2 car
# Speed: 74.3ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 117: 1080x1920 5.0ms, 4 person, 2 truck, 1 car
# Speed: 78.6ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 118: 1080x1920 5.3ms, 4 person, 2 truck, 1 car
# Speed: 88.8ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 119: 1080x1920 5.7ms, 4 person, 2 truck, 2 car
# Speed: 87.0ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 120: 1080x1920 4.9ms, 4 person, 2 truck, 1 car
# Speed: 80.5ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 121: 1080x1920 5.9ms, 4 person, 2 truck, 2 car
# Speed: 81.4ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 122: 1080x1920 5.4ms, 4 person, 2 truck, 1 car
# Speed: 80.8ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 123: 1080x1920 5.8ms, 4 person, 2 truck, 1 car
# Speed: 82.1ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 124: 1080x1920 5.7ms, 4 person, 2 truck, 1 car
# Speed: 73.3ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 125: 1080x1920 4.6ms, 4 person, 2 truck, 1 car
# Speed: 76.2ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 126: 1080x1920 5.6ms, 4 person, 2 truck, 1 car
# Speed: 80.2ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 127: 1080x1920 4.7ms, 4 person, 2 truck, 1 car
# Speed: 75.6ms track, 4.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 128: 1080x1920 4.9ms, 4 person, 2 truck, 1 car
# Speed: 75.6ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 129: 1080x1920 5.6ms, 4 person, 2 truck, 1 car
# Speed: 80.0ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 130: 1080x1920 5.9ms, 4 person, 2 truck, 1 car
# Speed: 83.4ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 131: 1080x1920 5.1ms, 4 person, 2 truck
# Speed: 81.3ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 132: 1080x1920 5.4ms, 4 person, 2 truck
# Speed: 84.0ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 133: 1080x1920 4.8ms, 4 person, 2 truck, 1 car
# Speed: 81.6ms track, 4.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 134: 1080x1920 5.5ms, 4 person, 2 truck
# Speed: 83.4ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 135: 1080x1920 6.0ms, 4 person, 2 truck, 1 car
# Speed: 75.0ms track, 6.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 136: 1080x1920 5.6ms, 4 person, 2 truck
# Speed: 80.8ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 137: 1080x1920 80.8ms, 4 person, 2 truck, 1 car
# Speed: 76.0ms track, 80.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 138: 1080x1920 26.7ms, 4 person, 2 truck, 1 car
# Speed: 94.0ms track, 26.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 139: 1080x1920 6.3ms, 4 person, 2 truck
# Speed: 84.8ms track, 6.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 140: 1080x1920 5.6ms, 4 person, 2 truck
# Speed: 75.6ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 141: 1080x1920 5.4ms, 4 person, 2 truck
# Speed: 77.2ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 142: 1080x1920 4.7ms, 4 person, 2 truck
# Speed: 83.3ms track, 4.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 143: 1080x1920 5.3ms, 4 person, 2 truck
# Speed: 83.3ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 144: 1080x1920 5.9ms, 4 person, 2 truck, 1 car
# Speed: 74.9ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 145: 1080x1920 6.3ms, 4 person, 2 truck, 1 car
# Speed: 95.3ms track, 6.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 146: 1080x1920 5.8ms, 4 person, 2 truck, 1 car
# Speed: 79.8ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 147: 1080x1920 5.3ms, 4 person, 2 truck, 1 car
# Speed: 83.1ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 148: 1080x1920 5.5ms, 4 person, 2 truck, 1 car
# Speed: 81.6ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 149: 1080x1920 6.1ms, 4 person, 2 truck, 1 car
# Speed: 91.9ms track, 6.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 150: 1080x1920 5.2ms, 4 person, 2 truck
# Speed: 85.2ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 151: 1080x1920 5.8ms, 4 person, 2 truck, 1 car
# Speed: 81.1ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 152: 1080x1920 5.2ms, 4 person, 2 truck
# Speed: 87.8ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 153: 1080x1920 5.3ms, 4 person, 2 truck, 1 car
# Speed: 84.8ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 154: 1080x1920 5.4ms, 4 person, 2 truck
# Speed: 84.6ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 155: 1080x1920 6.0ms, 4 person, 2 truck
# Speed: 84.4ms track, 6.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 156: 1080x1920 5.3ms, 4 person, 2 truck
# Speed: 89.1ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 157: 1080x1920 5.2ms, 4 person, 2 truck
# Speed: 83.9ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 158: 1080x1920 6.5ms, 4 person, 2 truck
# Speed: 111.0ms track, 6.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 159: 1080x1920 5.5ms, 4 person, 2 truck
# Speed: 85.4ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 160: 1080x1920 5.8ms, 4 person, 1 truck
# Speed: 85.3ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 161: 1080x1920 5.2ms, 4 person, 1 truck
# Speed: 85.3ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 162: 1080x1920 5.2ms, 4 person, 2 truck
# Speed: 83.4ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 163: 1080x1920 5.2ms, 4 person, 2 truck
# Speed: 83.5ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 164: 1080x1920 5.7ms, 4 person, 1 truck, 2 car
# Speed: 84.5ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 165: 1080x1920 5.1ms, 4 person, 1 truck
# Speed: 81.3ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 166: 1080x1920 4.9ms, 4 person, 1 truck
# Speed: 82.8ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 167: 1080x1920 5.3ms, 4 person, 1 truck, 1 car
# Speed: 84.5ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 168: 1080x1920 5.7ms, 4 person, 1 truck, 1 car
# Speed: 84.6ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 169: 1080x1920 5.1ms, 4 person, 1 truck, 1 car
# Speed: 85.0ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 170: 1080x1920 5.8ms, 4 person, 2 truck, 2 car
# Speed: 79.5ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 171: 1080x1920 6.2ms, 4 person, 2 truck, 2 car
# Speed: 82.9ms track, 6.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 172: 1080x1920 4.8ms, 4 person, 2 truck, 2 car
# Speed: 79.9ms track, 4.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 173: 1080x1920 5.5ms, 4 person, 2 truck, 2 car
# Speed: 83.3ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 174: 1080x1920 5.8ms, 4 person, 2 truck, 2 car
# Speed: 81.9ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 175: 1080x1920 5.5ms, 4 person, 2 truck, 2 car
# Speed: 84.0ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 29
#      25     video_writer.release()
#      26     cv2.destroyAllWindows()
# ---> 29 count_objects_in_region("data/marathon.mp4", "data/output_video.avi", "yolo11n.pt")
#
# Cell In[1], line 21, in count_objects_in_region(video_path, output_video_path, model_path)
#      19         print("Video frame is empty or processing is complete.")
#      20         break
# ---> 21     results = counter(im0)
#      22     video_writer.write(results.plot_im)
#      24 cap.release()
#
# File s:\YOLO\pyenv\Lib\site-packages\ultralytics\solutions\solutions.py:243, in BaseSolution.__call__(self, *args, **kwargs)
#     241 """Allow instances to be called like a function with flexible arguments."""
#     242 with self.profilers[1]:
# --> 243     result = self.process(*args, **kwargs)  # Call the subclass-specific process method
#     244 track_or_predict = "predict" if type(self).__name__ == "ObjectCropper" else "track"
#     245 track_or_predict_speed = self.profilers[0].dt * 1e3
#
# File s:\YOLO\pyenv\Lib\site-packages\ultralytics\solutions\object_counter.py:170, in ObjectCounter.process(self, im0)
#     167 # Iterate over bounding boxes, track ids and classes index
#     168 for box, track_id, cls, conf in zip(self.boxes, self.track_ids, self.clss, self.confs):
#     169     # Draw bounding box and counting region
# --> 170     self.annotator.box_label(box, label=self.adjust_box_label(cls, conf, track_id), color=colors(cls, True))
#     171     self.store_tracking_history(track_id, box)  # Store track history
#     173     # Store previous position of track for object counting
#
# File s:\YOLO\pyenv\Lib\site-packages\ultralytics\utils\plotting.py:344, in Annotator.box_label(self, box, label, color, txt_color)
#     338 cv2.polylines(
#     339     self.im, [np.asarray(box, dtype=int)], True, color, self.lw
#     340 ) if multi_points else cv2.rectangle(
#     341     self.im, p1, (int(box[2]), int(box[3])), color, thickness=self.lw, lineType=cv2.LINE_AA
#     342 )
#     343 if label:
# --> 344     w, h = cv2.getTextSize(label, 0, fontScale=self.sf, thickness=self.tf)[0]  # text width, height
#     345     h += 3  # add pixels to pad text
#     346     outside = p1[1] >= h  # label fits outside box
#
# KeyboardInterrupt:

# %%
import cv2

from ultralytics import solutions


def count_specific_classes(video_path, output_video_path, model_path, classes_to_count):
    """Count specific classes of objects in a video."""
    cap = cv2.VideoCapture(video_path)
    assert cap.isOpened(), "Error reading video file"
    w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
    video_writer = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

    line_points = [(20, 400), (1080, 400)]
    counter = solutions.ObjectCounter(
    show=True,
    region=[(20, 400), (1080, 400)],
    model="yolo11n.pt",
    classes=[0],  # person
    tracker="bytetrack.yaml", 
    direction = 'up'
)

    while cap.isOpened():
        success, im0 = cap.read()
        if not success:
            print("Video frame is empty or processing is complete.")
            break
        results = counter(im0)
        video_writer.write(results.plot_im)

    cap.release()
    video_writer.release()
    cv2.destroyAllWindows()


count_specific_classes("data/marathon.mp4", "output_specific_classes.avi", "yolo11n.pt", [0, 2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 36
#      32     video_writer.release()
#      33     cv2.destroyAllWindows()
# ---> 36 count_specific_classes("data/marathon.mp4", "output_specific_classes.avi", "yolo11n.pt", [0, 2])
#
# Cell In[4], line 14, in count_specific_classes(video_path, output_video_path, model_path, classes_to_count)
#      11     video_writer = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))
#      13     line_points = [(20, 400), (1080, 400)]
# ---> 14     counter = solutions.ObjectCounter(
#      15     show=True,
#      16     region=[(20, 400), (1080, 400)],
#      17     model="yolo11n.pt",
#      18     classes=[0],  # person
#      19     tracker="bytetrack.yaml",
#      20     direction = 'up'
#      21 )
#      23     while cap.isOpened():
#      24         success, im0 = cap.read()
#
# File s:\YOLO\pyenv\Lib\site-packages\ultralytics\solutions\object_counter.py:42, in ObjectCounter.__init__(self, **kwargs)
#      40 def __init__(self, **kwargs: Any) -> None:
#      41     """Initialize the ObjectCounter class for real-time object counting in video streams."""
# ---> 42     super().__init__(**kwargs)
#      44     self.in_count = 0  # Counter for objects moving inward
#      45     self.out_count = 0  # Counter for objects moving outward
#
# File s:\YOLO\pyenv\Lib\site-packages\ultralytics\solutions\solutions.py:81, in BaseSolution.__init__(self, is_cli, **kwargs)
#      74 def __init__(self, is_cli: bool = False, **kwargs: Any) -> None:
#      75     """Initialize the BaseSolution class with configuration settings and YOLO model.
#      76
#      77     Args:
#      78         is_cli (bool): Enable CLI mode if set to True.
#      79         **kwargs (Any): Additional configuration parameters that override defaults.
#      80     """
# ---> 81     self.CFG = vars(SolutionConfig().update(**kwargs))
#      82     self.LOGGER = LOGGER  # Store logger object to be used in multiple solution classes
#      84     check_requirements("shapely>=2.0.0")
#
# File s:\YOLO\pyenv\Lib\site-packages\ultralytics\solutions\config.py:105, in SolutionConfig.update(self, **kwargs)
#     103     else:
#     104         url = "https://docs.ultralytics.com/solutions/#solutions-arguments"
# --> 105         raise ValueError(f"{key} is not a valid solution argument, see {url}")
#     107 return self
#
# ValueError: direction is not a valid solution argument, see https://docs.ultralytics.com/solutions/#solutions-arguments

# %%
import cv2
from ultralytics import solutions

def count_people(video_path, output_path):
    cap = cv2.VideoCapture(video_path)
    assert cap.isOpened(), "Could not open video"

    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    writer = cv2.VideoWriter(
        output_path,
        cv2.VideoWriter_fourcc(*"mp4v"),
        fps,
        (w, h)
    )

    # VERY IMPORTANT: thin horizontal line
    line = [(0, int(h * 0.6)), (w, int(h * 0.6))]

    counter = solutions.ObjectCounter(
        model="yolo11n.pt",
        region=line,
        classes=[0],          # person
        tracker="bytetrack.yaml",
        show=True
    )

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        results = counter(frame)
        writer.write(results.plot_im)

    cap.release()
    writer.release()
    cv2.destroyAllWindows()

count_people("data/marathon.mp4", "output_count.mp4")
# Out:
# Ultralytics Solutions:  {'source': None, 'model': 'yolo11n.pt', 'classes': [0], 'show_conf': True, 'show_labels': True, 'region': [(0, 648), (1920, 648)], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'bytetrack.yaml', 'verbose': True, 'data': 'images'}
# 0: 1080x1920 5.0ms, 5 person
# Speed: 80.5ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 1: 1080x1920 5.0ms, 5 person
# Speed: 45.8ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 2: 1080x1920 5.9ms, 5 person
# Speed: 44.6ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 3: 1080x1920 5.6ms, 5 person
# Speed: 48.2ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 4: 1080x1920 5.0ms, 5 person
# Speed: 45.0ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 5: 1080x1920 5.3ms, 5 person
# Speed: 46.3ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 6: 1080x1920 5.6ms, 6 person
# Speed: 46.0ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 7: 1080x1920 4.6ms, 5 person
# Speed: 44.8ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 8: 1080x1920 5.2ms, 5 person
# Speed: 48.3ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 9: 1080x1920 5.3ms, 6 person
# Speed: 44.8ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 10: 1080x1920 5.5ms, 6 person
# Speed: 45.8ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 11: 1080x1920 5.0ms, 6 person
# Speed: 48.2ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 12: 1080x1920 5.4ms, 6 person
# Speed: 43.4ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 13: 1080x1920 5.1ms, 4 person
# Speed: 46.8ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 14: 1080x1920 5.8ms, 5 person
# Speed: 63.2ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 15: 1080x1920 5.5ms, 5 person
# Speed: 50.2ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 16: 1080x1920 5.3ms, 5 person
# Speed: 47.6ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 17: 1080x1920 5.6ms, 5 person
# Speed: 44.3ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 18: 1080x1920 4.9ms, 5 person
# Speed: 45.0ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 19: 1080x1920 4.6ms, 5 person
# Speed: 44.6ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 20: 1080x1920 5.1ms, 4 person
# Speed: 47.8ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 21: 1080x1920 5.2ms, 4 person
# Speed: 43.8ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 22: 1080x1920 4.6ms, 5 person
# Speed: 46.7ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 23: 1080x1920 5.6ms, 4 person
# Speed: 46.7ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 24: 1080x1920 4.6ms, 4 person
# Speed: 46.4ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 25: 1080x1920 5.0ms, 4 person
# Speed: 44.6ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 26: 1080x1920 4.7ms, 4 person
# Speed: 46.6ms track, 4.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 27: 1080x1920 5.1ms, 4 person
# Speed: 46.8ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 28: 1080x1920 5.5ms, 4 person
# Speed: 47.8ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 29: 1080x1920 4.9ms, 4 person
# Speed: 46.8ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 30: 1080x1920 5.1ms, 4 person
# Speed: 46.4ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 31: 1080x1920 5.3ms, 5 person
# Speed: 44.3ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 32: 1080x1920 5.4ms, 7 person
# Speed: 46.7ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 33: 1080x1920 5.4ms, 6 person
# Speed: 45.8ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 34: 1080x1920 5.5ms, 5 person
# Speed: 46.6ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 35: 1080x1920 5.2ms, 5 person
# Speed: 46.0ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 36: 1080x1920 5.2ms, 5 person
# Speed: 46.1ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 37: 1080x1920 5.1ms, 4 person
# Speed: 45.1ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 38: 1080x1920 5.5ms, 5 person
# Speed: 47.1ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 39: 1080x1920 4.7ms, 5 person
# Speed: 47.4ms track, 4.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 40: 1080x1920 5.0ms, 5 person
# Speed: 46.3ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 41: 1080x1920 5.0ms, 5 person
# Speed: 45.3ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 42: 1080x1920 5.1ms, 5 person
# Speed: 46.0ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 43: 1080x1920 5.6ms, 4 person
# Speed: 46.9ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 44: 1080x1920 5.9ms, 4 person
# Speed: 47.9ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 45: 1080x1920 4.9ms, 4 person
# Speed: 43.8ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 46: 1080x1920 10.0ms, 4 person
# Speed: 44.7ms track, 10.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 47: 1080x1920 5.2ms, 4 person
# Speed: 44.9ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 48: 1080x1920 5.1ms, 4 person
# Speed: 44.7ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 49: 1080x1920 5.8ms, 4 person
# Speed: 42.0ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 50: 1080x1920 4.9ms, 4 person
# Speed: 47.2ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 51: 1080x1920 4.0ms, 4 person
# Speed: 42.5ms track, 4.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 52: 1080x1920 5.5ms, 4 person
# Speed: 41.9ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 53: 1080x1920 4.7ms, 3 person
# Speed: 48.3ms track, 4.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 54: 1080x1920 4.9ms, 4 person
# Speed: 40.6ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 55: 1080x1920 5.1ms, 3 person
# Speed: 41.4ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 56: 1080x1920 5.2ms, 4 person
# Speed: 44.9ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 57: 1080x1920 5.7ms, 4 person
# Speed: 51.9ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 58: 1080x1920 5.2ms, 4 person
# Speed: 44.2ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 59: 1080x1920 5.0ms, 4 person
# Speed: 44.6ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 60: 1080x1920 4.0ms, 3 person
# Speed: 42.9ms track, 4.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 61: 1080x1920 3.9ms, 3 person
# Speed: 42.2ms track, 3.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 62: 1080x1920 4.0ms, 3 person
# Speed: 41.1ms track, 4.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 63: 1080x1920 4.9ms, 3 person
# Speed: 42.2ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 64: 1080x1920 4.6ms, 3 person
# Speed: 42.1ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 65: 1080x1920 3.8ms, 3 person
# Speed: 42.7ms track, 3.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 66: 1080x1920 4.8ms, 3 person
# Speed: 42.9ms track, 4.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 67: 1080x1920 4.8ms, 3 person
# Speed: 42.7ms track, 4.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 68: 1080x1920 5.4ms, 3 person
# Speed: 42.2ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 69: 1080x1920 4.7ms, 3 person
# Speed: 42.2ms track, 4.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 70: 1080x1920 3.9ms, 3 person
# Speed: 43.4ms track, 3.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 71: 1080x1920 4.7ms, 3 person
# Speed: 42.6ms track, 4.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 72: 1080x1920 5.2ms, 3 person
# Speed: 43.2ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 73: 1080x1920 5.3ms, 3 person
# Speed: 41.7ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 74: 1080x1920 4.9ms, 3 person
# Speed: 48.0ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 75: 1080x1920 4.9ms, 3 person
# Speed: 47.0ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 76: 1080x1920 4.8ms, 4 person
# Speed: 44.2ms track, 4.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 77: 1080x1920 5.2ms, 5 person
# Speed: 41.7ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 78: 1080x1920 5.0ms, 4 person
# Speed: 45.1ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 79: 1080x1920 5.0ms, 4 person
# Speed: 43.4ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 80: 1080x1920 4.9ms, 4 person
# Speed: 45.2ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 81: 1080x1920 5.0ms, 4 person
# Speed: 44.4ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 82: 1080x1920 5.5ms, 4 person
# Speed: 43.2ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 83: 1080x1920 5.1ms, 4 person
# Speed: 51.2ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 84: 1080x1920 5.1ms, 4 person
# Speed: 48.5ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 85: 1080x1920 4.9ms, 4 person
# Speed: 43.7ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 86: 1080x1920 4.9ms, 4 person
# Speed: 40.9ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 87: 1080x1920 5.3ms, 4 person
# Speed: 42.9ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 88: 1080x1920 5.0ms, 4 person
# Speed: 43.0ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 89: 1080x1920 5.0ms, 4 person
# Speed: 41.7ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 90: 1080x1920 5.0ms, 4 person
# Speed: 43.7ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 91: 1080x1920 4.9ms, 4 person
# Speed: 43.3ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 92: 1080x1920 4.5ms, 4 person
# Speed: 42.3ms track, 4.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 93: 1080x1920 5.6ms, 4 person
# Speed: 44.5ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 94: 1080x1920 5.1ms, 4 person
# Speed: 45.9ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 95: 1080x1920 5.3ms, 4 person
# Speed: 42.6ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 96: 1080x1920 4.9ms, 4 person
# Speed: 45.2ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 97: 1080x1920 5.5ms, 4 person
# Speed: 50.8ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 98: 1080x1920 5.1ms, 4 person
# Speed: 42.4ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 99: 1080x1920 4.2ms, 4 person
# Speed: 41.1ms track, 4.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 100: 1080x1920 6.0ms, 4 person
# Speed: 42.4ms track, 6.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 101: 1080x1920 5.2ms, 4 person
# Speed: 42.9ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 102: 1080x1920 4.5ms, 4 person
# Speed: 41.8ms track, 4.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 103: 1080x1920 4.9ms, 4 person
# Speed: 41.6ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 104: 1080x1920 5.0ms, 4 person
# Speed: 48.4ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 105: 1080x1920 5.5ms, 4 person
# Speed: 42.4ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 106: 1080x1920 4.9ms, 4 person
# Speed: 43.5ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 107: 1080x1920 4.9ms, 4 person
# Speed: 43.1ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 108: 1080x1920 4.9ms, 4 person
# Speed: 44.3ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 109: 1080x1920 4.9ms, 4 person
# Speed: 45.7ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 110: 1080x1920 5.2ms, 4 person
# Speed: 43.4ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 111: 1080x1920 5.3ms, 4 person
# Speed: 42.7ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 112: 1080x1920 5.8ms, 4 person
# Speed: 45.1ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 113: 1080x1920 4.9ms, 4 person
# Speed: 41.8ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 114: 1080x1920 6.1ms, 4 person
# Speed: 41.9ms track, 6.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 115: 1080x1920 5.6ms, 4 person
# Speed: 42.7ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 116: 1080x1920 4.2ms, 4 person
# Speed: 42.3ms track, 4.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 117: 1080x1920 5.3ms, 4 person
# Speed: 45.6ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 118: 1080x1920 5.3ms, 4 person
# Speed: 43.3ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 119: 1080x1920 5.2ms, 4 person
# Speed: 41.0ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 120: 1080x1920 5.6ms, 4 person
# Speed: 42.5ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 121: 1080x1920 6.2ms, 4 person
# Speed: 41.1ms track, 6.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 122: 1080x1920 5.1ms, 4 person
# Speed: 43.1ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 123: 1080x1920 5.0ms, 4 person
# Speed: 42.5ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 124: 1080x1920 5.4ms, 4 person
# Speed: 40.8ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 125: 1080x1920 5.7ms, 4 person
# Speed: 39.6ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 126: 1080x1920 6.1ms, 4 person
# Speed: 40.7ms track, 6.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 127: 1080x1920 5.9ms, 4 person
# Speed: 65.5ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 128: 1080x1920 5.1ms, 4 person
# Speed: 41.7ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 129: 1080x1920 5.2ms, 4 person
# Speed: 43.8ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 130: 1080x1920 4.6ms, 4 person
# Speed: 44.5ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 131: 1080x1920 5.3ms, 4 person
# Speed: 43.8ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 132: 1080x1920 5.9ms, 4 person
# Speed: 41.8ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 133: 1080x1920 5.6ms, 4 person
# Speed: 43.7ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 134: 1080x1920 5.5ms, 4 person
# Speed: 47.8ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 135: 1080x1920 5.0ms, 4 person
# Speed: 43.8ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 136: 1080x1920 5.1ms, 4 person
# Speed: 45.4ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 137: 1080x1920 5.2ms, 4 person
# Speed: 42.2ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 138: 1080x1920 4.3ms, 4 person
# Speed: 43.4ms track, 4.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 139: 1080x1920 4.9ms, 4 person
# Speed: 45.2ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 140: 1080x1920 5.1ms, 4 person
# Speed: 41.4ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 141: 1080x1920 5.5ms, 4 person
# Speed: 43.2ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 142: 1080x1920 4.9ms, 4 person
# Speed: 43.5ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 143: 1080x1920 5.1ms, 4 person
# Speed: 42.0ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 144: 1080x1920 5.6ms, 4 person
# Speed: 41.2ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 145: 1080x1920 5.6ms, 4 person
# Speed: 41.6ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 146: 1080x1920 5.0ms, 4 person
# Speed: 42.2ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 147: 1080x1920 4.9ms, 4 person
# Speed: 44.8ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 148: 1080x1920 5.8ms, 4 person
# Speed: 42.9ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 149: 1080x1920 5.1ms, 4 person
# Speed: 42.0ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 150: 1080x1920 4.8ms, 4 person
# Speed: 43.4ms track, 4.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 151: 1080x1920 5.1ms, 4 person
# Speed: 41.7ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 152: 1080x1920 5.3ms, 4 person
# Speed: 41.8ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 153: 1080x1920 5.4ms, 4 person
# Speed: 39.7ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 154: 1080x1920 4.8ms, 4 person
# Speed: 43.1ms track, 4.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 155: 1080x1920 5.0ms, 4 person
# Speed: 42.9ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 156: 1080x1920 5.1ms, 4 person
# Speed: 42.2ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 157: 1080x1920 4.9ms, 4 person
# Speed: 40.6ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 158: 1080x1920 5.6ms, 4 person
# Speed: 44.1ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 159: 1080x1920 5.0ms, 4 person
# Speed: 41.4ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 160: 1080x1920 4.9ms, 4 person
# Speed: 41.3ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 161: 1080x1920 5.1ms, 4 person
# Speed: 42.7ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 162: 1080x1920 5.3ms, 4 person
# Speed: 42.4ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 163: 1080x1920 5.0ms, 4 person
# Speed: 40.5ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 164: 1080x1920 4.3ms, 4 person
# Speed: 40.8ms track, 4.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 165: 1080x1920 5.8ms, 4 person
# Speed: 47.6ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 166: 1080x1920 5.0ms, 4 person
# Speed: 42.6ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 167: 1080x1920 5.5ms, 4 person
# Speed: 41.6ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 168: 1080x1920 5.4ms, 4 person
# Speed: 41.2ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 169: 1080x1920 5.3ms, 4 person
# Speed: 41.1ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 170: 1080x1920 4.3ms, 4 person
# Speed: 39.1ms track, 4.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 171: 1080x1920 4.6ms, 4 person
# Speed: 40.7ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 172: 1080x1920 5.0ms, 4 person
# Speed: 44.5ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 173: 1080x1920 5.0ms, 4 person
# Speed: 41.3ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 174: 1080x1920 4.7ms, 4 person
# Speed: 40.9ms track, 4.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 175: 1080x1920 5.0ms, 4 person
# Speed: 42.4ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 176: 1080x1920 5.0ms, 4 person
# Speed: 42.1ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 177: 1080x1920 4.3ms, 5 person
# Speed: 44.0ms track, 4.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 178: 1080x1920 5.9ms, 5 person
# Speed: 44.0ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 179: 1080x1920 5.7ms, 5 person
# Speed: 40.7ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 180: 1080x1920 5.3ms, 5 person
# Speed: 43.7ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 181: 1080x1920 5.1ms, 5 person
# Speed: 42.0ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 182: 1080x1920 5.2ms, 5 person
# Speed: 41.8ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 183: 1080x1920 5.2ms, 5 person
# Speed: 41.4ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 184: 1080x1920 5.1ms, 5 person
# Speed: 41.8ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 185: 1080x1920 4.9ms, 5 person
# Speed: 41.2ms track, 4.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 186: 1080x1920 6.2ms, 5 person
# Speed: 49.5ms track, 6.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 187: 1080x1920 5.1ms, 5 person
# Speed: 45.9ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 188: 1080x1920 5.5ms, 5 person
# Speed: 41.1ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 189: 1080x1920 4.1ms, 5 person
# Speed: 43.5ms track, 4.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 190: 1080x1920 5.0ms, 5 person
# Speed: 43.2ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 191: 1080x1920 5.9ms, 5 person
# Speed: 42.3ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 192: 1080x1920 5.1ms, 5 person
# Speed: 42.2ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 193: 1080x1920 5.1ms, 5 person
# Speed: 44.0ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 194: 1080x1920 4.6ms, 5 person
# Speed: 42.7ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 195: 1080x1920 5.1ms, 5 person
# Speed: 42.3ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 196: 1080x1920 5.6ms, 5 person
# Speed: 46.5ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 197: 1080x1920 5.5ms, 5 person
# Speed: 43.6ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 198: 1080x1920 5.0ms, 5 person
# Speed: 46.6ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 199: 1080x1920 5.2ms, 5 person
# Speed: 42.8ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 200: 1080x1920 5.4ms, 5 person
# Speed: 43.4ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 201: 1080x1920 5.2ms, 5 person
# Speed: 43.5ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 202: 1080x1920 5.5ms, 5 person
# Speed: 40.4ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 203: 1080x1920 5.8ms, 5 person
# Speed: 43.6ms track, 5.8ms solution per image at shape (1, 3, 1080, 1920)
#
# 204: 1080x1920 5.3ms, 5 person
# Speed: 45.2ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 205: 1080x1920 5.5ms, 5 person
# Speed: 51.5ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 206: 1080x1920 5.9ms, 5 person
# Speed: 46.9ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 207: 1080x1920 5.2ms, 5 person
# Speed: 44.4ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 208: 1080x1920 5.1ms, 5 person
# Speed: 43.7ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 209: 1080x1920 5.1ms, 5 person
# Speed: 41.8ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 210: 1080x1920 5.0ms, 5 person
# Speed: 53.0ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 211: 1080x1920 5.3ms, 5 person
# Speed: 41.4ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 212: 1080x1920 4.3ms, 5 person
# Speed: 44.0ms track, 4.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 213: 1080x1920 4.5ms, 5 person
# Speed: 44.5ms track, 4.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 214: 1080x1920 5.6ms, 5 person
# Speed: 40.7ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 215: 1080x1920 6.1ms, 5 person
# Speed: 41.0ms track, 6.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 216: 1080x1920 5.0ms, 5 person
# Speed: 46.7ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 217: 1080x1920 5.9ms, 5 person
# Speed: 42.1ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 218: 1080x1920 5.9ms, 5 person
# Speed: 43.1ms track, 5.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 219: 1080x1920 6.6ms, 5 person
# Speed: 52.4ms track, 6.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 220: 1080x1920 5.0ms, 5 person
# Speed: 44.0ms track, 5.0ms solution per image at shape (1, 3, 1080, 1920)
#
# 221: 1080x1920 5.1ms, 5 person
# Speed: 42.8ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 222: 1080x1920 5.7ms, 5 person
# Speed: 41.7ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 223: 1080x1920 5.1ms, 5 person
# Speed: 45.3ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 224: 1080x1920 5.6ms, 5 person
# Speed: 42.2ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 225: 1080x1920 4.6ms, 5 person
# Speed: 46.9ms track, 4.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 226: 1080x1920 5.3ms, 5 person
# Speed: 50.1ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 227: 1080x1920 5.5ms, 5 person
# Speed: 42.6ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 228: 1080x1920 5.4ms, 5 person
# Speed: 86.7ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 229: 1080x1920 5.3ms, 5 person
# Speed: 46.3ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 230: 1080x1920 5.5ms, 5 person
# Speed: 60.3ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 231: 1080x1920 5.7ms, 5 person
# Speed: 43.1ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 232: 1080x1920 5.5ms, 6 person
# Speed: 42.3ms track, 5.5ms solution per image at shape (1, 3, 1080, 1920)
#
# 233: 1080x1920 5.2ms, 6 person
# Speed: 46.7ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 234: 1080x1920 5.6ms, 6 person
# Speed: 47.9ms track, 5.6ms solution per image at shape (1, 3, 1080, 1920)
#
# 235: 1080x1920 5.2ms, 6 person
# Speed: 43.5ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 236: 1080x1920 5.3ms, 6 person
# Speed: 44.1ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 237: 1080x1920 5.4ms, 6 person
# Speed: 43.7ms track, 5.4ms solution per image at shape (1, 3, 1080, 1920)
#
# 238: 1080x1920 7.9ms, 6 person
# Speed: 105.2ms track, 7.9ms solution per image at shape (1, 3, 1080, 1920)
#
# 239: 1080x1920 5.1ms, 6 person
# Speed: 47.6ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 240: 1080x1920 5.2ms, 6 person
# Speed: 43.4ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 241: 1080x1920 5.1ms, 5 person
# Speed: 41.4ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
#
# 242: 1080x1920 5.2ms, 5 person
# Speed: 41.7ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 243: 1080x1920 5.3ms, 5 person
# Speed: 44.1ms track, 5.3ms solution per image at shape (1, 3, 1080, 1920)
#
# 244: 1080x1920 5.7ms, 6 person
# Speed: 41.4ms track, 5.7ms solution per image at shape (1, 3, 1080, 1920)
#
# 245: 1080x1920 5.2ms, 6 person
# Speed: 43.1ms track, 5.2ms solution per image at shape (1, 3, 1080, 1920)
#
# 246: 1080x1920 5.1ms, 6 person
# Speed: 44.2ms track, 5.1ms solution per image at shape (1, 3, 1080, 1920)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 42
#      39     writer.release()
#      40     cv2.destroyAllWindows()
# ---> 42 count_people("data/marathon.mp4", "output_count.mp4")
#
# Cell In[6], line 36, in count_people(video_path, output_path)
#      33         break
#      35     results = counter(frame)
# ---> 36     writer.write(results.plot_im)
#      38 cap.release()
#      39 writer.release()
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import torch

# Load YOLOv5 model, only person class
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
model.classes = [0]  # person class

cap = cv2.VideoCapture(0)
multi_tracker = cv2.MultiTracker_create()

unique_ids = set()
id_count = 0

detect_interval = 30  # run detection every 30 frames
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_count += 1

    if frame_count % detect_interval == 1:
        # Run detection
        results = model(frame)
        multi_tracker = cv2.MultiTracker_create()  # reset trackers each detection cycle
        boxes = []

        for *box, conf, cls in results.xyxy[0].tolist():
            x1, y1, x2, y2 = map(int, box)
            w, h = x2 - x1, y2 - y1
            boxes.append((x1, y1, w, h))

        # Initialize trackers for each detected box
        for box in boxes:
            tracker = cv2.TrackerCSRT_create()
            multi_tracker.add(tracker, frame, box)

        # Assign new IDs for all detected objects
        unique_ids.update(range(id_count, id_count + len(boxes)))
        id_count += len(boxes)

    else:
        # Update trackers
        success, boxes = multi_tracker.update(frame)

    # Draw bounding boxes
    if boxes:
        for i, box in enumerate(boxes):
            x, y, w, h = map(int, box)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.putText(frame, f'ID: {i}', (x, y - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    cv2.putText(frame, f'Unique persons: {len(unique_ids)}', (20, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0, 0, 255), 3)

    cv2.imshow('frame', frame)
    if cv2.waitKey(1) == 27:  # ESC to quit
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Using cache found in C:\Users\Adnan Habib/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2025-12-16 Python-3.13.7 torch-2.9.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 9
#       6 model.classes = [0]  # person class
#       8 cap = cv2.VideoCapture(0)
# ----> 9 multi_tracker = cv2.MultiTracker_create()
#      11 unique_ids = set()
#      12 id_count = 0
#
# AttributeError: module 'cv2' has no attribute 'MultiTracker_create'

# %%
import cv2
print(cv2.__version__)
print(hasattr(cv2, 'MultiTracker_create'))
# Out:
# 4.12.0
# False
